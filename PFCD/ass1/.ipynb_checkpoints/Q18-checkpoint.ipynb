# %%
import pandas as pd

clist = [10, 20, 30, 40, 50, 60, 70, 80, 90]
ctok = lambda c: c + 273.15
klist = list(map(ctok, clist))
print(klist)
# Out:
# [283.15, 293.15, 303.15, 313.15, 323.15, 333.15, 343.15, 353.15, 363.15]
